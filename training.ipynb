# %%
# %cd drive/My\ Drive/SF-GAN
# Out:
# /content/drive/My Drive/SF-GAN

# %%
# !pip install livelossplot

# %%
# %reload_ext autoreload
# %autoreload 2
from train import train

# %%
opt = {'epoch': 0,
       'n_epochs': 20,
       'batchSize': 1,
       'root': '/content/drive/My Drive/SF-GAN/',
       'lr_GS' : 0.0000002,
       'lr_AS': 0.00002,
       'decay_epoch': 10,
       'size': 256,
       'input_nc': 3,
       'output_nc': 3,
       'cuda': True,
       'checkpoints_dir': '/content/drive/My Drive/SF-GAN/checkpoints/',
       'out_dir': '/content/drive/My Drive/SF-GAN/output/',
       'resume_checkpoint': None,
       'AS_checkpoint': '/content/drive/My Drive/SF-GAN/checkpoints/AS_updated_mask_2.pth',
       'G0_checkpoint': None, #'/content/drive/My Drive/SF-GAN/checkpoints/icdar_updated_bg_changed.pth',
       'run_name': 'total_training_2',
       'n_cpu': 8
       }

# %%
train(opt)
# Out:
# loss_D1
# 	loss_D1          	 (min:    0.295, max:    0.324, cur:    0.306)
# loss_D2
# 	loss_D2          	 (min:    0.332, max:    0.535, cur:    0.445)
# loss_G
# 	loss_G           	 (min:    1.728, max:    2.613, cur:    1.728)
# loss_G0
# 	loss_G0          	 (min:    0.089, max:    0.241, cur:    0.110)
#
# Epoch 020/020 [0590/0593] -- loss_G0: 0.1117 | loss_G: 1.6633 | loss_D1: 0.3087 | loss_D2: 0.4459 -- ETA: 0:00:02.740732
