# %%
# %cd drive/My\ Drive/SF-GAN
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/SF-GAN'
# /content/drive/My Drive/SF-GAN

# %%
# !pip install livelossplot

# %%
# %reload_ext autoreload
# %autoreload 2
from train import train

# %%
# type1 : cheind
# type2 : warbean
# type3: affine

opt = {'epoch': 0,
       'n_epochs': 20,
       'batchSize': 1,
       'root': '/content/drive/My Drive/SF-GAN/',
       'lr': 0.000002,
       'decay_epoch': 10,
       'size': 256,
       'input_nc': 3,
       'output_nc': 3,
       'cuda': True,
       'checkpoints_dir': '/content/drive/My Drive/SF-GAN/checkpoints/',
       'out_dir': '/content/drive/My Drive/SF-GAN/output/',
       'resume_checkpoint': None, #'/content/drive/My Drive/SF-GAN/checkpoints/mse_loss_dropout2.pth',
       'run_name': 'icdar_updated_bg_changed',
       'n_cpu': 8,
       'stn_type': 1
       }

# %%
train(opt)
# Out:
# loss_D2
# 	loss_D2          	 (min:    0.229, max:    0.248, cur:    0.233)
# loss_G0
# 	loss_G0          	 (min:    0.258, max:    0.286, cur:    0.278)
