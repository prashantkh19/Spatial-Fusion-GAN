# %%
# %cd drive/My\ Drive/SF-GAN
# Out:
# /content/drive/My Drive/SF-GAN

# %%
# !pip install livelossplot

# %%
# %reload_ext autoreload
# %autoreload 2
from train_AS import train

# %%
opt = {'epoch': 0,
       'n_epochs': 40,
       'batchSize': 1,
       'root': '/content/drive/My Drive/SF-GAN/',
       'lr': 0.00002,
       'decay_epoch': 35,
       'size': 256,
       'input_nc': 3,
       'output_nc': 3,
       'cuda': True,
       'checkpoints_dir': '/content/drive/My Drive/SF-GAN/checkpoints/',
       'out_dir': '/content/drive/My Drive/SF-GAN/output/',
       'resume_checkpoint': '/content/drive/My Drive/SF-GAN/checkpoints/AS_updated_mask_1.pth',
       'G0_checkpoint': None, #'/content/drive/My Drive/SF-GAN/checkpoints/icdar_updated_bg_changed.pth',
       'run_name': 'AS_updated_mask_2',
       'n_cpu': 8
       }

# %%
train(opt)
# Out:
# loss_D1
# 	loss_D1          	 (min:    0.292, max:    0.318, cur:    0.301)
# loss_D2
# 	loss_D2          	 (min:    0.269, max:    0.303, cur:    0.303)
# loss_G
# 	loss_G           	 (min:    2.001, max:    2.942, cur:    2.001)
