# %%
# %cd drive/My\ Drive/SF-GAN
# Out:
# /content/drive/My Drive/SF-GAN

# %%
# !pip install livelossplot

# %%
# %reload_ext autoreload
# %autoreload 2
from train_AS import train

# %%
opt = {'epoch': 0,
       'n_epochs': 30,
       'batchSize': 1,
       'root': '/content/drive/My Drive/SF-GAN/',
       'lr': 0.000002,
       'decay_epoch': 10,
       'size': 256,
       'input_nc': 3,
       'output_nc': 3,
       'cuda': True,
       'checkpoints_dir': '/content/drive/My Drive/SF-GAN/checkpoints/',
       'out_dir': '/content/drive/My Drive/SF-GAN/output/',
       'resume_checkpoint': None, #'/content/drive/My Drive/SF-GAN/checkpoints/mse_loss_dropout2.pth',
       'G0_checkpoint': '/content/drive/My Drive/SF-GAN/checkpoints/icdar_updated_bg_changed.pth',
       'run_name': 'AS_GF_eps_r_3',
       'n_cpu': 8
       }

# %%
train(opt)
# Out:
# loss_D1
# 	loss_D1          	 (min:    0.216, max:    0.348, cur:    0.234)
# loss_D2
# 	loss_D2          	 (min:    0.208, max:    0.441, cur:    0.220)
# loss_G
# 	loss_G           	 (min:    7.317, max:    7.474, cur:    7.335)
#
# Epoch 022/030 [0367/0593] -- loss_G: 7.1938 | loss_D1: 0.2159 | loss_D2: 0.2358 -- ETA: 0:57:41.662200
